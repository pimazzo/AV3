# %%
import matplotlib.pyplot as plt

# Carregar os dados do arquivo stars.txt
data = []
with open('stars.txt', 'r') as file:
    for line in file:
        values = line.strip().split()
        data.append([float(v) for v in values])

# Converter os dados para listas de coordenadas x e y
x = [row[0] for row in data]
y = [row[1] for row in data]

# Criar o gráfico scatter
plt.scatter(x, y, color='blue', alpha=0.5)
plt.title('Scatter Plot of Stars')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.grid(True)
plt.show()

# %%
from altair import sphere
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
spacing=2
# Plot all points in a single figure with spacing
for i in range(-L, L + 1,spacing):
    for j in range(-L, L + 1,spacing):
        for k in range(-L, L + 1,spacing):
            ax.scatter(i, j, k, s=R * 200, alpha=0.5,color='blue')
ax.view_init(elev=20, azim=23)  

plt.show()
